# %% [markdown]
# <a href="https://colab.research.google.com/github/anitaannah/Time_Series_Project/blob/main/air_passengers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing required libraries


import matplotlib.pyplot as plt #plotting
import numpy as np #Linear  Algebra
import pandas as pd #data processig
import datetime
from pandas import Grouper
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.stattools import adfuller
from pandas.plotting import autocorrelation_plot
from matplotlib.pylab import rcParams
rcParams ['figure.figsize']=10,6
from numpy import log

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5b0e06f0-1029-4eb1-99f9-56b3f6e13b72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b0e06f0-1029-4eb1-99f9-56b3f6e13b72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AirPassengers.csv to AirPassengers (1).csv

# %%
import pandas as pd
import io
  
df = pd.read_csv(io.BytesIO(uploaded['AirPassengers.csv']))
print(df)
df.shape
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]
# (144, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
#converting to Date Column to DateTime format

df['Month'] = pd.to_datetime(df['Month'],infer_datetime_format=True)  #convert from string
df=df.set_index(['Month'])
df.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
#Visualization

#Line Plot

df.plot()
plt.show()

# %%
#scatter plot
df.plot(style='k.')
plt.show()

# %%
# density plot

df.plot(kind='kde')
plt.show()

# %%
#Box Plot
df=read_csv('AirPassengers.csv',header=0,index_col=0,parse_dates=True,squeeze=True)
gp=df.groupby(Grouper(freq='A'))
years=DataFrame()
for Month,group in gp:
  years [Month.year]=group.values
  years.boxplot()
  plt.show()

# %%
#autocorrelation plot
autocorrelation_plot(df)
plt.show()

# %%
#multiple plots in single figure window using subplot
plt.figure(1)
plt.subplot(221)
df.plot(legend='AirPassenger',title='original',xlabel='')
plt.subplot(222)
df.hist()

# %%
#to remove trend by applying differencing operation
dr=df.diff()

# %%
plt.figure(1)
plt.subplot(221)
df.plot(legend='AirPassenger',title='original',xlabel='')
plt.subplot(222)
df.hist()
dfs.plot(legend='Diff(df)',title='After applying Difference',xlabel='')
dfs.hist()
plt.show()

# %%
#task 4 
#stationarity check
